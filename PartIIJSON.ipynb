# %%
url = 'https://www.liquidation.com/c/sony.html'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
from bs4 import BeautifulSoup
import main
import csv
import requests


class Listing:
    def __init__(self, title, link, date, manifest, minbid, totalCost, maxbid, gross, net):
        self.title = title
        self.link = link
        self.date = date
        self.manifest = manifest
        self.minbid = minbid
        self.totalCost = totalCost
        self.maxbid = maxbid
        self.gross = gross
        self.net = net

#url = 'https://www.liquidation.com/c/sony.html'

# Configure Selenium to use headless mode
options = Options()
options.add_argument("--headless")

# Set up the WebDriver
driver = webdriver.Chrome()

def listingLinks(url):
    """returns links of Liqudation listings found on given url"""

    auctionLinks = []
    
    # Open the website
    driver.get(url)

    # Wait for JavaScript to load content (optional wait strategy)
    #driver.implicitly_wait(10)

    # Extract HTML content
    page_source = driver.page_source

    for element in driver.find_elements(By.CLASS_NAME, 'thumbnail'):
        try:
            if element.find_element(By.CLASS_NAME,"closing").text == "CLOSED":
                pass
            else:
                auctionLinks.append(element.find_element(By.CLASS_NAME, "desc").get_attribute('href'))
        except:
            continue

    #for element in driver.find_elements(By.CLASS_NAME, "desc"):
        #auctionLinks.append(element.get_attribute("href"))
    
    return set(auctionLinks)

def manifestRead(manifestlink):
    """Takes in the manifest link of a listing and uses all of the functions from previous manifest reader to return gross profit and costs"""
    

    driver.get(manifestlink)
    
    manifestHTML = BeautifulSoup(driver.page_source, "html.parser")

    table = manifestHTML.find("table")

    # Extract table headers
    headers = [th.text.strip() for th in table.find_all("th")]

    # Extract table rows
    data = []
    for row in table.find_all("tr")[1:]:  # Skip the header row
        cells = row.find_all("td")
        row_data = [cell.text.strip() for cell in cells]
        if row_data:
            data.append(row_data)

    manifest = pd.DataFrame(data)

    #removes bottom row of totals from dataframe
    manifest = manifest.drop(manifest.index[-1])

    soldPrices = []
    allSold = []
    allShipping = []


    report = pd.DataFrame(columns = ['Item', 'Quantity', 'Price', 'Shipping', 'Net'])
    n = 0
    for item in manifest.loc[:,0]:
        #Goes through each item in list and finds quantity, average price, and average shipping, calucating net and adding data to find total value

        quantity = float(manifest.loc[n,1])

        if item in priceData:
            
            avgSold = priceData[item][0]
            avgShip = priceData[item][1]
            print("Skipped eBay research on item" + item)
        else:

            link = f'https://www.ebay.com/sch/i.html?_nkw={item.replace(" ","+")}&LH_Sold=1&LH_Complete=1&rt=nc&LH_ItemCondition=1000'

            soldListings = BeautifulSoup(requests.get(link).text,"html.parser")
            avgSold = float(main.averageSold(soldListings)*quantity)
        
            avgShip, freeShip = main.avgShipping(soldListings)
            priceData[item] = [avgSold, avgShip]
            print("Did not skip eBay research on item" + item)

        allSold.append(avgSold)
        allShipping.append(avgShip)
        
        net = (avgSold*.92) - avgShip
        itemInfo = {'Item': item, 'Quantity': quantity, 'Price': avgSold, 'Shipping': avgShip, 'Net': round(net,2)}
        report.loc[len(report)] = itemInfo

        n = n + 1

    totalFees = round(sum(allSold)*(.08), 2)
    grossProfit = round(sum(allSold) - totalFees - sum(allShipping), 2)
    
    return grossProfit, report




#currently errors on listings with 5 minutes left in the auction as page html changes, can fix by just skipping these in the auction links function
def listScrape(auctionLinks):
    """Creates an object for each listing containing all information about the listing, returning all data in a list of objects"""
    allListings = []

    n = 0

    for listing in auctionLinks:

        print("Reading Data from this link:" + listing)

        driver.get(listing)
        #driver.implicitly_wait(10)
        title = driver.find_element(By.XPATH, '//*[@id="auctionData"]/h1/b').text
        date = driver.find_element(By.XPATH, '//*[@id="auctionData"]/div[2]/div[2]/b').text
        manifestLink = driver.find_element(By.XPATH, '//*[@id="auctionData"]/ul/li[1]/a[1]').get_attribute('href')
        minbid = driver.find_element(By.XPATH, "//*[@id='auctionData']/div[3]/div[2]/b").text

        grossProfit, manifestReport = manifestRead(manifestLink)

        allListings.append(Listing(title = title, link = listing, date = date, manifest = manifestReport, minbid = minbid, totalCost= 0, maxbid= 0, gross = grossProfit, net = grossProfit))
    
    return allListings
        


#manifestRead('https://www.liquidation.com/aucimg/19707/m19707411.html')

#Dictionary of other price data stored as {Item Name: [avg sold price, avg shipping]}
priceData = {}

auctionData = listScrape(listingLinks(url))
df = pd.DataFrame(Listing.__dict__ for Listing in auctionData)
print(df)

driver.quit()
# Out:
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19766119
# Did not skip eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19661489
# Did not skip eBay research on itemSONY WH1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WH1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WH1000XM5/B Headphone (BT)
# Did not skip eBay research on itemSONY WH1000XM5/L Headphone (BT)
# Skipped eBay research on itemSONY WH1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WH1000XM5/B Headphone (BT)
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19773285
# Did not skip eBay research on itemSONY WFC700N/B Headphone (BT)
# Did not skip eBay research on itemSONY WHRF400 Headphones
# Skipped eBay research on itemSONY WHRF400 Headphones
# Skipped eBay research on itemSONY WHRF400 Headphones
# Skipped eBay research on itemSONY WHRF400 Headphones
# Skipped eBay research on itemSONY WHRF400 Headphones
# Skipped eBay research on itemSONY WHRF400 Headphones
# Skipped eBay research on itemSONY WHRF400 Headphones
# Skipped eBay research on itemSONY WHRF400 Headphones
# Skipped eBay research on itemSONY WHRF400 Headphones
# Skipped eBay research on itemSONY WHRF400 Headphones
# Did not skip eBay research on itemSony MDRZX110 ZX Series Stereo Headphones (White)
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19827980
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Did not skip eBay research on itemSONY SRSXE300/H Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Did not skip eBay research on itemSONY SRSXE200/H Personal Audio
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19662443
# Did not skip eBay research on itemSONY SRSXG300/B Personal Audio
# Skipped eBay research on itemSONY SRSXG300/B Personal Audio
# Skipped eBay research on itemSONY SRSXG300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19822032
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/H Personal Audio
# Skipped eBay research on itemSONY SRSXE300/H Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19838026
# Did not skip eBay research on itemSONY XR55A80L TVs
# Did not skip eBay research on itemSONY K85S30 TVs
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19780204
# Did not skip eBay research on itemSONY WHCH520/B Headphone (BT)
# Did not skip eBay research on itemSONY WHCH520/C Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Did not skip eBay research on itemSONY WFC510BRF Headphone (BT)
# Skipped eBay research on itemSONY WFC510BRF Headphone (BT)
# Skipped eBay research on itemSONY WFC510BRF Headphone (BT)
# Did not skip eBay research on itemSONY WFC510/L Headphone (BT)
# Skipped eBay research on itemSONY WFC510/L Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WFC510BRF Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/C Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WFC510BRF Headphone (BT)
# Did not skip eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Skipped eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Skipped eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Skipped eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Skipped eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Skipped eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Skipped eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Did not skip eBay research on itemSONY MDREX155AP/B Headphones
# Skipped eBay research on itemSONY MDREX155AP/B Headphones
# Skipped eBay research on itemSONY MDREX155AP/B Headphones
# Skipped eBay research on itemSony MDRZX110 ZX Series Stereo Headphones (White)
# Did not skip eBay research on itemSony MDRZX110/BLK Headphones
# Skipped eBay research on itemSony MDRZX110 ZX Series Stereo Headphones (White)
# Skipped eBay research on itemSony MDRZX110/BLK Headphones
# Skipped eBay research on itemSony MDRZX110/BLK Headphones
# Skipped eBay research on itemSony MDRZX110/BLK Headphones
# Did not skip eBay research on itemSony MDREX14AP/B Headphones
# Skipped eBay research on itemSony MDREX14AP/B Headphones
# Skipped eBay research on itemSony MDREX14AP/B Headphones
# Did not skip eBay research on itemSony MDREX14AP/W Headphones
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19661111
# Did not skip eBay research on itemSONY WH1000XM4/S Headphone (BT)
# Did not skip eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Did not skip eBay research on itemSONY WF1000XM5/S Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/S Headphone (BT)
# Did not skip eBay research on itemSONY WFLS900N/B Headphone (BT)
# Did not skip eBay research on itemSONY WFLS900N/W Headphone (BT)
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19701516
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/S Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WFLS900N/W Headphone (BT)
# Did not skip eBay research on itemSONY WFL900/W Headphone (BT)
# Did not skip eBay research on itemSONY WFL900/H Headphone (BT)
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19775878
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/S Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Did not skip eBay research on itemSONY WHCH720N/B Headphone (BT)
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19833833
# Did not skip eBay research on itemSONY XBR85X81CH TVs
# Did not skip eBay research on itemSONY XR75X90CJ TVs
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19781157
# Did not skip eBay research on itemSONY SRSXG300/BZ Personal Audio
# Did not skip eBay research on itemSONY SRSXG300/HZ Personal Audio
# Skipped eBay research on itemSONY SRSXG300/HZ Personal Audio
# Did not skip eBay research on itemSONY SRSXE200/B Personal Audio
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19773050
# Skipped eBay research on itemSONY WFC700N/B Headphone (BT)
# Skipped eBay research on itemSONY WFC700N/B Headphone (BT)
# Did not skip eBay research on itemSONY WFC700N/V Headphone (BT)
# Skipped eBay research on itemSONY WHRF400 Headphones
# Did not skip eBay research on itemSONY WHCH520/L Headphone (BT)
# Skipped eBay research on itemSONY WFC510BRF Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/L Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Did not skip eBay research on itemSony MDRZX310AP/B Headphones
# Did not skip eBay research on itemSONY WIC100/L Headphones
# Did not skip eBay research on itemSony MDRZX310AP/W Headphones
# Did not skip eBay research on itemSony MDREX110AP/B Headphones
# Skipped eBay research on itemSony MDREX110AP/B Headphones
# Skipped eBay research on itemSony MDRZX110 ZX Series Stereo Headphones (White)
# Skipped eBay research on itemSony MDRZX110/BLK Headphones
# Skipped eBay research on itemSony MDRZX110 ZX Series Stereo Headphones (White)
# Did not skip eBay research on itemSony MDREX15LP/B Headphones
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19781144
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Did not skip eBay research on itemSONY WF1000XM4/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM4/B Headphone (BT)
# Did not skip eBay research on itemSONY WFLS910N/B Headphones
# Skipped eBay research on itemSONY WFLS900N/B Headphone (BT)
# Skipped eBay research on itemSONY WFLS900N/B Headphone (BT)
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19827964
# Did not skip eBay research on itemSONY SRSXG300/H Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/H Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19828088
# Skipped eBay research on itemSONY SRSXG300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19781452
# Skipped eBay research on itemSONY WF1000XM5/S Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Did not skip eBay research on itemSONY WFL910/B Headphones
# Skipped eBay research on itemSONY WFC700N/B Headphone (BT)
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19828241
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/H Personal Audio
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19781174
# Skipped eBay research on itemSONY WH1000XM5/B Headphone (BT)
# Did not skip eBay research on itemSONY WH1000XM4/B Headphone (BT)
# Did not skip eBay research on itemSONY WH1000XM4/L Headphone (BT)
# Skipped eBay research on itemSONY WH1000XM4/L Headphone (BT)
# Skipped eBay research on itemSONY WH1000XM4/S Headphone (BT)
# Did not skip eBay research on itemSONY WHCH720N/L Headphone (BT)
# Skipped eBay research on itemSONY WHCH720N/L Headphone (BT)
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19775861
# Skipped eBay research on itemSONY WH1000XM5/L Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/S Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WFLS910N/B Headphones
# Skipped eBay research on itemSONY WFC700N/B Headphone (BT)
# Did not skip eBay research on itemSONY WFC700N/G Headphone (BT)
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19828203
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/H Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19773041
# Did not skip eBay research on itemSony BDPS3700 Streaming Blu-Ray Disc Player with Wi-Fi (2016 Canada Model)
# Skipped eBay research on itemSony BDPS3700 Streaming Blu-Ray Disc Player with Wi-Fi (2016 Canada Model)
# Skipped eBay research on itemSony BDPS3700 Streaming Blu-Ray Disc Player with Wi-Fi (2016 Canada Model)
# Skipped eBay research on itemSony BDPS3700 Streaming Blu-Ray Disc Player with Wi-Fi (2016 Canada Model)
# Skipped eBay research on itemSony BDPS3700 Streaming Blu-Ray Disc Player with Wi-Fi (2016 Canada Model)
# Skipped eBay research on itemSony BDPS3700 Streaming Blu-Ray Disc Player with Wi-Fi (2016 Canada Model)
# Skipped eBay research on itemSony BDPS3700 Streaming Blu-Ray Disc Player with Wi-Fi (2016 Canada Model)
# Skipped eBay research on itemSony BDPS3700 Streaming Blu-Ray Disc Player with Wi-Fi (2016 Canada Model)
# Did not skip eBay research on itemSony BDPS1700 Blu-Ray DiscTM Player
# Skipped eBay research on itemSony BDPS1700 Blu-Ray DiscTM Player
# Skipped eBay research on itemSony BDPS1700 Blu-Ray DiscTM Player
# Did not skip eBay research on itemSony DVPSR510H DVD Player (Upscaling)
# Skipped eBay research on itemSony DVPSR510H DVD Player (Upscaling)
# Skipped eBay research on itemSony DVPSR510H DVD Player (Upscaling)
# Skipped eBay research on itemSony DVPSR510H DVD Player (Upscaling)
# Skipped eBay research on itemSony DVPSR510H DVD Player (Upscaling)
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19781238
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/C Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WFC510BRF Headphone (BT)
# Skipped eBay research on itemSONY WFC510BRF Headphone (BT)
# Skipped eBay research on itemSONY WFC510BRF Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/C Headphone (BT)
# Skipped eBay research on itemSONY WFC510BRF Headphone (BT)
# Skipped eBay research on itemSONY WFC510BRF Headphone (BT)
# Skipped eBay research on itemSONY WFC510/L Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/C Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/B Headphone (BT)
# Skipped eBay research on itemSONY WHCH520/C Headphone (BT)
# Skipped eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Skipped eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Skipped eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Skipped eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Skipped eBay research on itemSony MDRZX110NC On-Ear Noise Cancelling Headphones (Black)
# Skipped eBay research on itemSONY MDREX155AP/B Headphones
# Skipped eBay research on itemSONY MDREX155AP/B Headphones
# Skipped eBay research on itemSONY MDREX155AP/B Headphones
# Skipped eBay research on itemSONY MDREX155AP/B Headphones
# Skipped eBay research on itemSONY MDREX155AP/B Headphones
# Skipped eBay research on itemSony MDRZX110 ZX Series Stereo Headphones (White)
# Skipped eBay research on itemSony MDRZX110/BLK Headphones
# Skipped eBay research on itemSony MDRZX110/BLK Headphones
# Skipped eBay research on itemSony MDRZX110 ZX Series Stereo Headphones (White)
# Skipped eBay research on itemSony MDRZX110/BLK Headphones
# Skipped eBay research on itemSony MDREX14AP/B Headphones
# Skipped eBay research on itemSony MDREX14AP/W Headphones
# Skipped eBay research on itemSony MDREX14AP/B Headphones
# Skipped eBay research on itemSony MDREX14AP/W Headphones
# Skipped eBay research on itemSony MDREX14AP/B Headphones
# Skipped eBay research on itemSony MDREX14AP/B Headphones
# Skipped eBay research on itemSony MDREX14AP/B Headphones
# Skipped eBay research on itemSony MDREX14AP/B Headphones
# Skipped eBay research on itemSony MDREX14AP/B Headphones
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19799155
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19828019
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Skipped eBay research on itemSONY SRSXE300/H Personal Audio
# Skipped eBay research on itemSONY SRSXE300/H Personal Audio
# Skipped eBay research on itemSONY SRSXE300/H Personal Audio
# Skipped eBay research on itemSONY SRSXE300/B Personal Audio
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19775839
# Skipped eBay research on itemSONY WH1000XM5/L Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WFLS900N/B Headphone (BT)
# Skipped eBay research on itemSONY WFLS900N/B Headphone (BT)
# Skipped eBay research on itemSONY WFC700N/B Headphone (BT)
# Reading Data from this link:http://www.liquidation.com/auction/view?id=19701617
# Skipped eBay research on itemSONY WF1000XM5/S Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WF1000XM5/B Headphone (BT)
# Skipped eBay research on itemSONY WFLS900N/W Headphone (BT)
# Skipped eBay research on itemSONY WFLS900N/W Headphone (BT)
# Skipped eBay research on itemSONY WFLS900N/B Headphone (BT)
# Skipped eBay research on itemSONY WFLS900N/B Headphone (BT)
# Skipped eBay research on itemSONY WFLS900N/B Headphone (BT)
# Did not skip eBay research on itemSONY WFLS900N/L Headphone (BT)
# Skipped eBay research on itemSONY WFL900/H Headphone (BT)
#                                                 title  \
# 0   A Grade - Sony Portable Audio Systems - MSRP $999
# 1   Salvage Sony Noise Canceling Headphones - MSRP...
# 2       Sony Noise Canceling Headphones - MSRP $2,034
# 3   A Grade - Sony Portable Audio Systems - MSRP $929
# 4    Sony Extra Bass Bluetooth Speakers - MSRP $1,249
# 5   A Grade - Sony Portable Audio Systems - MSRP $999
# 6   B Grade - Sony 55"- 85" 4K Ultra HD Smart LED ...
# 7       Sony Noise Canceling Headphones - MSRP $2,059
# 8   C Grade - Sony Noise Canceling Bluetooth Headp...
# 9   Salvage Sony Noise Canceling Headphones - MSRP...
# 10  C Grade - Sony Noise Canceling Headphones - MS...
# 11  D Grade - Sony 75"- 85" 4K Ultra HD Smart LED ...
# 12  C Grade - Sony Portable Audio Systems - MSRP $...
# 13      Sony Noise Canceling Headphones - MSRP $1,832
# 14  C Grade - Sony Noise Canceling Headphones - MS...
# 15  A Grade - Sony Portable Audio Systems - MSRP $...
# 16  A Grade - Sony Portable Audio Systems - MSRP $...
# 17  C Grade - Sony Noise Canceling Headphones - MS...
# 18  A Grade - Sony Portable Audio Systems - MSRP $999
# 19  C Grade - Sony Noise Canceling Headphones - MS...
# 20  C Grade - Sony Noise Canceling Headphones - MS...
# 21  A Grade - Sony Portable Audio Systems - MSRP $999
# 22            Sony DVD & BluRay Players - MSRP $1,544
# 23      Sony Noise Canceling Headphones - MSRP $2,014
# 24  A Grade Sony Extra Bass Bluetooth Speakers - M...
# 25  A Grade - Sony Portable Audio Systems - MSRP $999
# 26  C Grade - Sony Noise Canceling Headphones - MS...
# 27  Salvage Sony Noise Canceling Headphones - MSRP...
#
#                                                  link  \
# 0   http://www.liquidation.com/auction/view?id=197...
# 1   http://www.liquidation.com/auction/view?id=196...
# 2   http://www.liquidation.com/auction/view?id=197...
# 3   http://www.liquidation.com/auction/view?id=198...
# 4   http://www.liquidation.com/auction/view?id=196...
# 5   http://www.liquidation.com/auction/view?id=198...
# 6   http://www.liquidation.com/auction/view?id=198...
# 7   http://www.liquidation.com/auction/view?id=197...
# 8   http://www.liquidation.com/auction/view?id=196...
# 9   http://www.liquidation.com/auction/view?id=197...
# 10  http://www.liquidation.com/auction/view?id=197...
# 11  http://www.liquidation.com/auction/view?id=198...
# 12  http://www.liquidation.com/auction/view?id=197...
# 13  http://www.liquidation.com/auction/view?id=197...
# 14  http://www.liquidation.com/auction/view?id=197...
# 15  http://www.liquidation.com/auction/view?id=198...
# 16  http://www.liquidation.com/auction/view?id=198...
# 17  http://www.liquidation.com/auction/view?id=197...
# 18  http://www.liquidation.com/auction/view?id=198...
# 19  http://www.liquidation.com/auction/view?id=197...
# 20  http://www.liquidation.com/auction/view?id=197...
# 21  http://www.liquidation.com/auction/view?id=198...
# 22  http://www.liquidation.com/auction/view?id=197...
# 23  http://www.liquidation.com/auction/view?id=197...
# 24  http://www.liquidation.com/auction/view?id=197...
# 25  http://www.liquidation.com/auction/view?id=198...
# 26  http://www.liquidation.com/auction/view?id=197...
# 27  http://www.liquidation.com/auction/view?id=197...
#
#                                 date  \
# 0    (CLOSES 02/06/2025 6:50 PM EST)
# 1    (CLOSES 02/07/2025 3:40 PM EST)
# 2   (CLOSES 02/07/2025 09:15 AM EST)
# 3    (CLOSES 02/06/2025 8:25 PM EST)
# 4    (CLOSES 02/07/2025 2:55 PM EST)
# 5    (CLOSES 02/06/2025 5:55 PM EST)
# 6    (CLOSES 02/07/2025 2:25 PM EST)
# 7    (CLOSES 02/07/2025 2:50 PM EST)
# 8    (CLOSES 02/06/2025 9:50 PM EST)
# 9    (CLOSES 02/06/2025 8:50 PM EST)
# 10   (CLOSES 02/06/2025 5:25 PM EST)
# 11  (CLOSES 02/07/2025 11:50 AM EST)
# 12  (CLOSES 02/07/2025 12:50 PM EST)
# 13  (CLOSES 02/07/2025 09:55 AM EST)
# 14   (CLOSES 02/07/2025 1:50 PM EST)
# 15   (CLOSES 02/06/2025 9:25 PM EST)
# 16   (CLOSES 02/07/2025 1:15 PM EST)
# 17  (CLOSES 02/07/2025 09:50 AM EST)
# 18   (CLOSES 02/06/2025 5:40 PM EST)
# 19  (CLOSES 02/07/2025 11:50 AM EST)
# 20   (CLOSES 02/06/2025 6:15 PM EST)
# 21   (CLOSES 02/06/2025 6:25 PM EST)
# 22  (CLOSES 02/07/2025 11:45 AM EST)
# 23  (CLOSES 02/07/2025 10:50 AM EST)
# 24   (CLOSES 02/06/2025 6:55 PM EST)
# 25   (CLOSES 02/06/2025 7:25 PM EST)
# 26   (CLOSES 02/06/2025 8:15 PM EST)
# 27   (CLOSES 02/06/2025 7:50 PM EST)
#
#                                              manifest    minbid  totalCost  \
# 0                                Item  Quantity  P...   $135.00          0
# 1                                 Item  Quantity  ...    $50.00          0
# 2                                                 ...  C$210.00          0
# 3                                Item  Quantity   ...   $150.00          0
# 4                                Item  Quantity   ...   $100.00          0
# 5                                Item  Quantity   ...   $136.00          0
# 6                   Item  Quantity   Price  Shippi...   $500.00          0
# 7                                                 ...   $100.00          0
# 8                                 Item  Quantity  ...   $412.00          0
# 9                                 Item  Quantity  ...   $150.00          0
# 10                                Item  Quantity  ...   $353.00          0
# 11                    Item  Quantity  Price  Shipp...   $209.00          0
# 12                                Item  Quantity  ...   $100.00          0
# 13                                                ...  C$140.00          0
# 14                                Item  Quantity  ...   $100.00          0
# 15                               Item  Quantity   ...   $150.00          0
# 16                               Item  Quantity   ...   $150.00          0
# 17                                Item  Quantity  ...   $160.00          0
# 18                               Item  Quantity   ...   $150.00          0
# 19                                Item  Quantity  ...   $163.00          0
# 20                                Item  Quantity  ...   $341.00          0
# 21                               Item  Quantity   ...   $150.00          0
# 22                                                ...  C$151.00          0
# 23                                                ...   $100.00          0
# 24                               Item  Quantity  P...   $150.00          0
# 25                               Item  Quantity   ...   $150.00          0
# 26                                Item  Quantity  ...   $280.10          0
# 27                                 Item  Quantity ...   $110.00          0
#
#     maxbid    gross      net
# 0        0   446.91   446.91
# 1        0   883.45   883.45
# 2        0   805.64   805.64
# 3        0   369.31   369.31
# 4        0   437.24   437.24
# 5        0   370.69   370.69
# 6        0  1177.57  1177.57
# 7        0  1191.24  1191.24
# 8        0  1245.84  1245.84
# 9        0  1026.72  1026.72
# 10       0   991.89   991.89
# 11       0   623.64   623.64
# 12       0    93.53    93.53
# 13       0   682.11   682.11
# 14       0  1050.20  1050.20
# 15       0   361.54   361.54
# 16       0   473.48   473.48
# 17       0   823.00   823.00
# 18       0   408.80   408.80
# 19       0   768.14   768.14
# 20       0   910.45   910.45
# 21       0   408.80   408.80
# 22       0   213.21   213.21
# 23       0  1185.36  1185.36
# 24       0   446.91   446.91
# 25       0   332.58   332.58
# 26       0   936.40   936.40
# 27       0  1117.20  1117.20
